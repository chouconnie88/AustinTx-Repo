# %%
#packages
import pandas as pd
import warnings
from sklearn.exceptions import ConvergenceWarning
import s3fs

# %%
# Filter out multiple warning categories
warnings.filterwarnings('ignore', category=ConvergenceWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.set_option('mode.chained_assignment', None)

# %%
# Define your S3 bucket and folder

# Define the full S3 path to the file
s3_file_path = 's3://keepaustinweird/austin_key/data.csv'

# Read the file into a Pandas DataFrame
filtered_df = pd.read_csv(s3_file_path)

# Display the DataFrame
filtered_df.head()
# Out:
#               published_date   issue_reported   latitude  longitude  \
# 0  2024-01-24 23:32:05+00:00  Stalled Vehicle   0.000000   0.000000
# 1  2024-01-01 04:39:24+00:00     VEHICLE FIRE  30.376018 -97.501944
# 2  2024-01-01 07:05:26+00:00    Crash Service  30.302704 -97.661269
# 3  2024-01-01 10:53:42+00:00    Crash Service  30.385992 -97.672917
# 4  2024-01-01 05:01:41+00:00        COLLISION  30.344979 -97.580056
#
#                                  address traffic_report_status  \
# 0                             200 Dedman              ARCHIVED
# 1                    14614 BOIS D ARC RD              ARCHIVED
# 2  Loyola Ln / Ed Bluestein Blvd Svrd Sb              ARCHIVED
# 3                       11900 N IH 35 NB              ARCHIVED
# 4       10212-10256 E US 290 HWY SVRD WB              ARCHIVED
#
#   traffic_report_status_date_time
# 0        2024-01-25T00:15:11.000Z
# 1        2024-01-01T05:10:08.000Z
# 2        2024-01-01T10:30:07.000Z
# 3        2024-01-01T18:00:09.000Z
# 4        2024-01-01T06:15:08.000Z

# %%
#MAPPING AUSTIN

#drop longitude and latitude where it is 0,0 and drop na values
value_to_drop = 0
filtered_df2 = filtered_df[(filtered_df['longitude'] != value_to_drop) & (filtered_df["latitude"] != value_to_drop)]
filtered_df2 = filtered_df2.dropna()

#creating a new df with just longitude, latitude, and incident type
mapping_df = filtered_df2[["issue_reported", "latitude", "longitude"]]
mapping_df.head()
# Out:
#   issue_reported   latitude  longitude
# 1   VEHICLE FIRE  30.376018 -97.501944
# 2  Crash Service  30.302704 -97.661269
# 3  Crash Service  30.385992 -97.672917
# 4      COLLISION  30.344979 -97.580056
# 5   Crash Urgent  30.356958 -97.679610

# %%
from math import radians, sin, cos, sqrt, atan2

def haversine_distance(lat1, lon1, lat2, lon2):
    # Radius of the Earth in kilometers
    R = 6371.0
    
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    # Calculate the differences in coordinates
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    # Haversine formula
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    # Calculate the distance
    distance = R * c

    return distance

# Example usage with the coordinates you provided (30.271, -97.743)
target_coordinates = (30.271, -97.743)
# other_coordinates = (your_other_latitude, your_other_longitude)  # Replace with your own coordinates

# distance = haversine_distance(target_coordinates[0], target_coordinates[1],
#                               other_coordinates[0], other_coordinates[1])

# print(f"The distance between the coordinates is {distance:.2f} kilometers.")

# %%
# Function to calculate distances and create a new column in the DataFrame
def calculate_distances(row):
    target_coordinates = (30.271, -97.743)
    return haversine_distance(target_coordinates[0], target_coordinates[1], row['latitude'], row['longitude'])

# Apply the function to each row and create a new 'Distance' column
mapping_df['Distance_from_dt'] = mapping_df.apply(calculate_distances, axis=1)

# Display the updated DataFrame
print(mapping_df)
# Out:
#                   issue_reported   latitude  longitude  Distance_from_dt
# 1                   VEHICLE FIRE  30.376018 -97.501944         25.916930
# 2                  Crash Service  30.302704 -97.661269          8.603114
# 3                  Crash Service  30.385992 -97.672917         14.447816
# 4                      COLLISION  30.344979 -97.580056         17.673335
# 5                   Crash Urgent  30.356958 -97.679610         11.330630
# ...                          ...        ...        ...               ...
# 5338               Crash Service  30.306688 -97.709208          5.125903
# 5339                Crash Urgent  30.239250 -97.687710          6.376990
# 5340                Crash Urgent  30.391021 -97.671945         14.987122
# 5341  COLLISION/PRIVATE PROPERTY  30.180994 -97.688027         11.316375
# 5342             LOOSE LIVESTOCK  30.277369 -97.503367         23.022961
#
# [5323 rows x 4 columns]

# %%
def classify_location(distance):
    if distance < 1.5:
        return 'Downtown'
    else:
        return 'Not Downtown'

# Function to calculate distances and create a new column in the DataFrame
def calculate_distances(row):
    target_coordinates = (30.271, -97.743)
    return haversine_distance(target_coordinates[0], target_coordinates[1], row['latitude'], row['longitude'])

# Apply the function to each row and create a new 'Distance' column
mapping_df['Distance'] = mapping_df.apply(calculate_distances, axis=1)

# Create a new column 'Location_Class' based on the distances
mapping_df['Location_Class'] = mapping_df['Distance'].apply(classify_location)

# %%
mapping_df.Location_Class.value_counts()
# Out:
# Location_Class
# Not Downtown    5091
# Downtown         232
# Name: count, dtype: int64

# %%
# Function to calculate distances and create a new column in the DataFrame
def calculate_distances_UT(row):
    target_coordinates = (30.285, -97.7335)
    return haversine_distance(target_coordinates[0], target_coordinates[1], row['latitude'], row['longitude'])

# Apply the function to each row and create a new 'Distance' column
mapping_df['Distance_from_UT'] = mapping_df.apply(calculate_distances_UT, axis=1)

# Display the updated DataFrame
print(mapping_df)
# Out:
#                   issue_reported   latitude  longitude  Distance_from_dt  \
# 1                   VEHICLE FIRE  30.376018 -97.501944         25.916930
# 2                  Crash Service  30.302704 -97.661269          8.603114
# 3                  Crash Service  30.385992 -97.672917         14.447816
# 4                      COLLISION  30.344979 -97.580056         17.673335
# 5                   Crash Urgent  30.356958 -97.679610         11.330630
# ...                          ...        ...        ...               ...
# 5338               Crash Service  30.306688 -97.709208          5.125903
# 5339                Crash Urgent  30.239250 -97.687710          6.376990
# 5340                Crash Urgent  30.391021 -97.671945         14.987122
# 5341  COLLISION/PRIVATE PROPERTY  30.180994 -97.688027         11.316375
# 5342             LOOSE LIVESTOCK  30.277369 -97.503367         23.022961
#
#        Distance Location_Class  Distance_from_UT
# 1     25.916930   Not Downtown         24.419666
# 2      8.603114   Not Downtown          7.208981
# 3     14.447816   Not Downtown         12.645671
# 4     17.673335   Not Downtown         16.168758
# 5     11.330630   Not Downtown          9.527736
# ...         ...            ...               ...
# 5338   5.125903   Not Downtown          3.354880
# 5339   6.376990   Not Downtown          6.724560
# 5340  14.987122   Not Downtown         13.186232
# 5341  11.316375   Not Downtown         12.362552
# 5342  23.022961   Not Downtown         22.114486
#
# [5323 rows x 7 columns]

# %%
mapping_df.head()
# Out:
#   issue_reported   latitude  longitude  Distance_from_dt   Distance  \
# 1   VEHICLE FIRE  30.376018 -97.501944         25.916930  25.916930
# 2  Crash Service  30.302704 -97.661269          8.603114   8.603114
# 3  Crash Service  30.385992 -97.672917         14.447816  14.447816
# 4      COLLISION  30.344979 -97.580056         17.673335  17.673335
# 5   Crash Urgent  30.356958 -97.679610         11.330630  11.330630
#
#   Location_Class  Distance_from_UT
# 1   Not Downtown         24.419666
# 2   Not Downtown          7.208981
# 3   Not Downtown         12.645671
# 4   Not Downtown         16.168758
# 5   Not Downtown          9.527736

# %%
# Function to classify points as "Close to Campus" or "not"
def classify_location_UT(distance):
    if distance < 2.0:
        return 'Close to UT Austin'
    else:
        return 'Not Close'

# Apply the function to each row and create a new 'Distance' column
mapping_df['Distance_UT'] = mapping_df.apply(calculate_distances_UT, axis=1)

# Create a new column 'Location_Class' based on the distances
mapping_df['Location_Class_UT'] = mapping_df['Distance_UT'].apply(classify_location_UT)

# %%
mapping_df
# Out:
#                   issue_reported   latitude  longitude  Distance_from_dt  \
# 1                   VEHICLE FIRE  30.376018 -97.501944         25.916930
# 2                  Crash Service  30.302704 -97.661269          8.603114
# 3                  Crash Service  30.385992 -97.672917         14.447816
# 4                      COLLISION  30.344979 -97.580056         17.673335
# 5                   Crash Urgent  30.356958 -97.679610         11.330630
# ...                          ...        ...        ...               ...
# 5338               Crash Service  30.306688 -97.709208          5.125903
# 5339                Crash Urgent  30.239250 -97.687710          6.376990
# 5340                Crash Urgent  30.391021 -97.671945         14.987122
# 5341  COLLISION/PRIVATE PROPERTY  30.180994 -97.688027         11.316375
# 5342             LOOSE LIVESTOCK  30.277369 -97.503367         23.022961
#
#        Distance Location_Class  Distance_from_UT  Distance_UT  \
# 1     25.916930   Not Downtown         24.419666    24.419666
# 2      8.603114   Not Downtown          7.208981     7.208981
# 3     14.447816   Not Downtown         12.645671    12.645671
# 4     17.673335   Not Downtown         16.168758    16.168758
# 5     11.330630   Not Downtown          9.527736     9.527736
# ...         ...            ...               ...          ...
# 5338   5.125903   Not Downtown          3.354880     3.354880
# 5339   6.376990   Not Downtown          6.724560     6.724560
# 5340  14.987122   Not Downtown         13.186232    13.186232
# 5341  11.316375   Not Downtown         12.362552    12.362552
# 5342  23.022961   Not Downtown         22.114486    22.114486
#
#      Location_Class_UT
# 1            Not Close
# 2            Not Close
# 3            Not Close
# 4            Not Close
# 5            Not Close
# ...                ...
# 5338         Not Close
# 5339         Not Close
# 5340         Not Close
# 5341         Not Close
# 5342         Not Close
#
# [5323 rows x 9 columns]

# %%
mapping_df.Location_Class_UT.value_counts()
# Out:
# Location_Class_UT
# Not Close             5118
# Close to UT Austin     205
# Name: count, dtype: int64

# %%
# Filter the DataFrame based on conditions
filtered_data = mapping_df[(mapping_df['Location_Class'] == 'Downtown') & (mapping_df['Location_Class_UT'] == 'Close to UT Austin')]

# Count the number of observations
count_observations = len(filtered_data)

print(f"The number of observations that are both 'Downtown' and 'Close to Campus' is: {count_observations}")
# Out:
# The number of observations that are both 'Downtown' and 'Close to Campus' is: 95

# %%
import numpy as np

# Define your conditions and corresponding values
conditions = [
    (mapping_df['Location_Class'] == 'Downtown') & (mapping_df['Location_Class_UT'] == 'Not Close'),
    (mapping_df['Location_Class'] == 'Not Downtown') & (mapping_df['Location_Class_UT'] == 'Close to UT Austin'),
    (mapping_df['Location_Class'] == 'Downtown') & (mapping_df['Location_Class_UT'] == 'Close to UT Austin'),
    (mapping_df['Location_Class'] == 'Not Downtown') & (mapping_df['Location_Class_UT'] == 'Not Close')
]

values = [
    'Only Downtown',  # Value when Condition 1 is True
    'Only Close to Campus',  # Value when Condition 2 is True
    'Both', # Value when Condition 3 is True
    "Neither" 
    
]

# Create a new column based on the conditions
mapping_df['Location_Overlap'] = np.select(conditions, values)

# %%
mapping_df.head()
# Out:
#   issue_reported   latitude  longitude  Distance_from_dt   Distance  \
# 1   VEHICLE FIRE  30.376018 -97.501944         25.916930  25.916930
# 2  Crash Service  30.302704 -97.661269          8.603114   8.603114
# 3  Crash Service  30.385992 -97.672917         14.447816  14.447816
# 4      COLLISION  30.344979 -97.580056         17.673335  17.673335
# 5   Crash Urgent  30.356958 -97.679610         11.330630  11.330630
#
#   Location_Class  Distance_from_UT  Distance_UT Location_Class_UT  \
# 1   Not Downtown         24.419666    24.419666         Not Close
# 2   Not Downtown          7.208981     7.208981         Not Close
# 3   Not Downtown         12.645671    12.645671         Not Close
# 4   Not Downtown         16.168758    16.168758         Not Close
# 5   Not Downtown          9.527736     9.527736         Not Close
#
#   Location_Overlap
# 1          Neither
# 2          Neither
# 3          Neither
# 4          Neither
# 5          Neither

# %%
# Filter the DataFrame based on conditions
filtered_overlap_data = mapping_df[mapping_df['Location_Overlap'] != 'Neither']

# %%
filtered_overlap_data
# Out:
#        issue_reported   latitude  longitude  Distance_from_dt  Distance  \
# 15       Crash Urgent  30.269211 -97.727084          1.541375  1.541375
# 24     Traffic Hazard  30.289294 -97.723449          2.768125  2.768125
# 30      Crash Service  30.267725 -97.734299          0.911508  0.911508
# 33       Crash Urgent  30.296906 -97.718262          3.733672  3.733672
# 40     Traffic Hazard  30.278546 -97.750713          1.119221  1.119221
# ...               ...        ...        ...               ...       ...
# 5279   Traffic Hazard  30.277309 -97.730359          1.402051  1.402051
# 5283     Crash Urgent  30.265685 -97.749119          0.833432  0.833432
# 5284  Stalled Vehicle  30.269905 -97.742114          0.148542  0.148542
# 5289  Stalled Vehicle  30.267431 -97.743544          0.400279  0.400279
# 5324     Crash Urgent  30.285380 -97.741778          1.603283  1.603283
#
#      Location_Class  Distance_from_UT  Distance_UT   Location_Class_UT  \
# 15     Not Downtown          1.860625     1.860625  Close to UT Austin
# 24     Not Downtown          1.076730     1.076730  Close to UT Austin
# 30         Downtown          1.922424     1.922424  Close to UT Austin
# 33     Not Downtown          1.973126     1.973126  Close to UT Austin
# 40         Downtown          1.801921     1.801921  Close to UT Austin
# ...             ...               ...          ...                 ...
# 5279       Downtown          0.906828     0.906828  Close to UT Austin
# 5283       Downtown          2.619617     2.619617           Not Close
# 5284       Downtown          1.871242     1.871242  Close to UT Austin
# 5289       Downtown          2.178708     2.178708           Not Close
# 5324   Not Downtown          0.795973     0.795973  Close to UT Austin
#
#           Location_Overlap
# 15    Only Close to Campus
# 24    Only Close to Campus
# 30                    Both
# 33    Only Close to Campus
# 40                    Both
# ...                    ...
# 5279                  Both
# 5283         Only Downtown
# 5284                  Both
# 5289         Only Downtown
# 5324  Only Close to Campus
#
# [342 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

counts = filtered_overlap_data.groupby("Location_Overlap").size().reset_index(name="Count")

# Create a bar plot
plt.bar(counts["Location_Overlap"], counts["Count"])
# Set plot labels and title
plt.xlabel("Location Overlap")
plt.ylabel("Count")
plt.title("Bar Plot using Matplotlib")

# Show the plot
plt.show()

# %%
counts
# Out:
#        Location_Overlap  Count
# 0                  Both     95
# 1  Only Close to Campus    110
# 2         Only Downtown    137

# %%
# !pip install plotnine
# Out:
# Requirement already satisfied: plotnine in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (0.13.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotnine) (3.8.2)
# Requirement already satisfied: pandas<3.0.0,>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotnine) (2.2.0)
# Requirement already satisfied: mizani~=0.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotnine) (0.11.0)
# Requirement already satisfied: numpy>=1.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotnine) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotnine) (1.12.0)
# Requirement already satisfied: statsmodels>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotnine) (0.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.6.0->plotnine) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.6.0->plotnine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.6.0->plotnine) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.6.0->plotnine) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.6.0->plotnine) (21.3)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.6.0->plotnine) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.6.0->plotnine) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib>=3.6.0->plotnine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.0->plotnine) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.0->plotnine) (2023.4)
# Requirement already satisfied: patsy>=0.5.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from statsmodels>=0.14.0->plotnine) (0.5.6)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from patsy>=0.5.4->statsmodels>=0.14.0->plotnine) (1.16.0)

# %%
from plotnine import *

# Create a column chart
(ggplot(counts, aes(x="Location_Overlap", y="Count",fill="Location_Overlap",color="Location_Overlap")) +
 geom_col() +
 labs(title='Count of Incidents by UT Austin/Downtown', x='Location Status', y='Count') +
 scale_fill_manual(values=("black","orange","white")) +
 scale_color_manual(values=("black","black","black")) +
 theme_minimal()+
 geom_text(aes(label='Count'),            # Add text labels at the top of each column
                  position=position_stack(vjust=1.05),           # Adjust the vertical position of labels
                  size=10, color='black') +
 theme(legend_position='none')) # Removing Legend for Location

# %%
# Looking at Issues Reported within Each Location Status group
issue_overlap_df = filtered_overlap_data.groupby('issue_reported')['Location_Overlap'].value_counts().reset_index()
issue_overlap_df
# Out:
#        issue_reported      Location_Overlap  count
# 0   COLLISN/ LVNG SCN                  Both      1
# 1       Crash Service  Only Close to Campus     21
# 2       Crash Service                  Both     12
# 3       Crash Service         Only Downtown     11
# 4        Crash Urgent  Only Close to Campus     44
# 5        Crash Urgent         Only Downtown     42
# 6        Crash Urgent                  Both     31
# 7   FLEET ACC/ INJURY         Only Downtown      2
# 8     Stalled Vehicle                  Both      8
# 9     Stalled Vehicle         Only Downtown      6
# 10    Stalled Vehicle  Only Close to Campus      5
# 11     Traffic Hazard         Only Downtown     76
# 12     Traffic Hazard                  Both     43
# 13     Traffic Hazard  Only Close to Campus     40

# %%
# Create a column chart

# Define a custom labelling function
def custom_labeller(label):
    return ''

(ggplot(issue_overlap_df, aes(x="reorder(issue_reported,count)", y="count",fill="Location_Overlap",color="Location_Overlap")) +
 geom_col() +
 facet_wrap("Location_Overlap", labeller=custom_labeller) +
 labs(title='Count of Incidents by UT Austin/Downtown', x='Location Status', y='Count',fill="Location Status") +
 scale_fill_manual(values=("black","orange","white")) +
 scale_color_manual(values=("black","black","black")) +
 theme_minimal()+
 geom_text(aes(label='count'),            # Add text labels at the top of each column
                  position=position_stack(vjust=1.05),           # Adjust the vertical position of labels
                  size=10, color='black') +
 
theme(axis_text_x=element_text(rotation=45, hjust=1)) +
 theme(figure_size=(12,7))) # Removing Legend for Location
